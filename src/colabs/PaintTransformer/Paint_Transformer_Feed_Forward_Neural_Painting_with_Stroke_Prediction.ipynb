# %% [markdown]
# <a href="https://colab.research.google.com/github/PrinceP/MonoRepo/blob/tf_learning/src/colabs/PaintTransformer/Paint_Transformer_Feed_Forward_Neural_Painting_with_Stroke_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python -m pip install paddlepaddle-gpu
# Out:
# ...
#      |████████████████████████████████| 361.4 MB 24 kB/s
# ...

# %%
#!git clone https://github.com/wzmsltw/PaintTransformer
#!cp /content/drive/MyDrive/TF_LEARNING/PAINT_TRANSFORMER/paint_best.pdparams PaintTransformer/inference
# !python PaintTransformer/inference/inference.py
# Out:
# W0814 13:54:42.248375   456 device_context.cc:404] Please NOTE: device: 0, GPU Compute Capability: 7.5, Driver API Version: 11.2, Runtime API Version: 10.2
# W0814 13:54:42.251785   456 device_context.cc:422] device: 0, cuDNN Version: 7.6.
# layer 0 cost: 0.26
# layer 1 cost: 0.20
# layer 2 cost: 0.30
# layer 3 cost: 0.59
# layer 4 cost: 1.56
# total frame: 171
# total infer time: 5.18740177154541

# %%
# !ls PaintTransformer/inference
# Out:
# brush	      network.py	   render_parallel.py
# inference.py  paint_best.pdparams  render_serial.py
# input	      __pycache__	   render_utils.py
