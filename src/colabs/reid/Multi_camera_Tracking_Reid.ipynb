# %% [markdown]
# <a href="https://colab.research.google.com/github/PrinceP/MonoRepo/blob/tf_learning/src/colabs/reid/Multi_camera_Tracking_Reid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/samihormi/Multi-Camera-Person-Tracking-and-Re-Identification

# %%
# !wget https://pjreddie.com/media/files/yolov3.weights

# %%
# !cd Multi-Camera-Person-Tracking-and-Re-Identification/ && ls && pip install -r requirements.txt

# %%
# !cd Multi-Camera-Person-Tracking-and-Re-Identification/ && mkdir model_data/weights && cp ../yolov3.weights model_data/weights/ && python convert_y3.py model_data/weights/yolov3.weights model_data/models/yolov3.h5

# %%
# !gdown --id 15Ayri_sHtrctJ1Zb8qERjvdi66y6QaI4

# %%
# !gdown --id 1EtkBARD398UW93HwiVO9x3mByr0AeWMg

# %%
# !wget https://github.com/intel-iot-devkit/sample-videos/raw/master/store-aisle-detection.mp4

# %%
# !pip install 'h5py<3.0.0'

# %%
# !cd Multi-Camera-Person-Tracking-and-Re-Identification/ && python demo.py --videos /content/store-aisle-detection.mp4 --version v3
